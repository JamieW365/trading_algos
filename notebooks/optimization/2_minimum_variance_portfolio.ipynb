# %% [markdown]
# # Minimum Variance Portfolio

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Data

# %% [markdown]
# ## Viz

# %% [markdown]
# ## Minimum Variance Portfolio

# %% [markdown]
# ## Summary Statistics
